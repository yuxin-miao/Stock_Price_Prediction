# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set()

# %%
score = [6538, 34674, 59450, 20779, 15185, 30738, 5090, 19064, 16094, 59139]
mo = [-6,-3,0,3,6,9,12,15,18, 21]
modelname = ['SES', 'Holt Linear', 'Holt Exponential', 'HWES add-add', 'HWES add-mul', 'SARIMA', 'AR', 'GLMM', 'ARIMA', "VAR"]

model = ['SES', 'Holt Linear', 'Holt Exponential', 'HWES add-add', 'HWES add-mul', 'SARIMA', 'AR', 'GLMM', 'ARIMA', "VAR"]
num = [1,1,1,1,1,1,1,4,5,4]
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np

# %%
clist = [(0, "red"), (0.125, "red"), (0.25, "orange"), (0.5, "green"), 
         (0.7, "green"), (0.75, "blue"), (1, "blue")]
rvb = mcolors.LinearSegmentedColormap.from_list("", clist)

# %%
# %matplotlib notebook
sns.set()
# fig,ax = plt.subplots()  
fig = plt.figure(figsize=(16,5)) 
x_pos = [i for i,_ in enumerate(model)]
sns.barplot(x_pos, score)
plt.xticks(x_pos, model)
for i, v in enumerate(score):
    plt.text(x_pos[i]-0.2, score[i] , str(v), fontweight='bold')
plt.show()
plt.savefig(fname="score.png")
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %%
sp = [a / 10.0 for a in score]

# %%
# %matplotlib notebook
colors = np.random.rand(len(num))  # 颜色数组
co = ['Pastel1', 'Pastel2', 'Paired', 'Accent',
                        'Dark2', 'Set1', 'Set2', 'Set3',
                        'tab10', 'tab20', 'tab20b', 'tab20c']
# size = production
# plt.figure(figsize=(30, 30))
plt.text(-6, 1,'SES', size = 15, alpha = 0.2)

# for x,y,text in mo,num,model:
#     plt.text(x, y,text, size = 15, alpha = 0.2)

# plt.text(-3, 3, "function: y = x * x", size = 15, alpha = 0.2)

plt.scatter(mo, num, s=sp, c=mo, alpha=0.6)  # 画散点图, alpha=0.6 表示不透明度为 0.6
plt.ylim([-3, 7])  # 纵坐标轴范围
plt.xlim([-10, 28])   # 横坐标轴范围
plt.xlabel('Model')  # 横坐标轴标题
plt.ylabel('Variable Number')  # 纵坐标轴标题
plt.show()
# plt.savefig(fname='socre.png')
# Out:
# <img src="data:image/png;base64,..." width="640">
